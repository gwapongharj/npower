# %%
import pandas as pd
import numpy as np

# %%
#Data is stored to the Data Frame by reading the CSV file through Pandas
df=pd.read_csv("/Users/harjin/Desktop/NPOWER/npower_git/npower/course_7/adult.csv")

# %%
#
df.describe(include="all")
# Out:
#                  age workclass        fnlwgt education  educational-num  \
# count   32561.000000     32561  3.256100e+04     32561     32561.000000
# unique           NaN         9           NaN        16              NaN
# top              NaN   Private           NaN   HS-grad              NaN
# freq             NaN     22696           NaN     10501              NaN
# mean       38.581647       NaN  1.897784e+05       NaN        10.080679
# std        13.640433       NaN  1.055500e+05       NaN         2.572720
# min        17.000000       NaN  1.228500e+04       NaN         1.000000
# 25%        28.000000       NaN  1.178270e+05       NaN         9.000000
# 50%        37.000000       NaN  1.783560e+05       NaN        10.000000
# 75%        48.000000       NaN  2.370510e+05       NaN        12.000000
# max        90.000000       NaN  1.484705e+06       NaN        16.000000
#
#              marital-status       occupation relationship    race gender  \
# ...

# %%
#df.replace(" ",np.nan,inplace=True)
df = df.map(lambda x: x.strip() if isinstance(x, str) else x) 
df.replace('?', np.nan,inplace=True)

# %%
df['gender'].value_counts()
# Out:
# gender
# Male      21790
# Female    10771
# Name: count, dtype: int64

# %%
df[['gender','age']].groupby(['gender'],as_index=False).mean()
# Out:
#    gender        age
# 0  Female  36.858230
# 1    Male  39.433547

# %%
percent_country = df['native-country'].value_counts(normalize=True)*100
print(percent_country['Germany'])
# Out:
# 0.42841953843267244

# %%
df[['income','age']].groupby(['income'],as_index=False).mean()
# Out:
#   income        age
# 0  <=50K  36.783738
# 1   >50K  44.249841

# %%
df[['income','age']].groupby(['income'],as_index=False).std()
# Out:
#   income        age
# 0  <=50K  14.020088
# 1   >50K  10.519028

# %%
df[df['income']=='>50K']['education'].value_counts()
# Out:
# education
# Bachelors       2221
# HS-grad         1675
# Some-college    1387
# Masters          959
# Prof-school      423
# Assoc-voc        361
# Doctorate        306
# Assoc-acdm       265
# 10th              62
# 11th              60
# 7th-8th           40
# 12th              33
# 9th               27
# 5th-6th           16
# 1st-4th            6
# Name: count, dtype: int64

# %%
df[['race','gender','age']].groupby(['gender','race'],as_index=False).describe()
# Out:
#    gender                race      age                                    \
#                                  count       mean        std   min   25%
# 0  Female  Amer-Indian-Eskimo    119.0  37.117647  13.114991  17.0  27.0
# 1  Female  Asian-Pac-Islander    346.0  35.089595  12.300845  17.0  25.0
# 2  Female               Black   1555.0  37.854019  12.637197  17.0  28.0
# 3  Female               Other    109.0  31.678899  11.631599  17.0  23.0
# 4  Female               White   8642.0  36.811618  14.329093  17.0  25.0
# 5    Male  Amer-Indian-Eskimo    192.0  37.208333  12.049563  17.0  28.0
# 6    Male  Asian-Pac-Islander    693.0  39.073593  12.883944  18.0  29.0
# 7    Male               Black   1569.0  37.682600  12.882612  17.0  27.0
# 8    Male               Other    162.0  34.654321  11.355531  17.0  26.0
# 9    Male               White  19174.0  39.652498  13.436029  17.0  29.0
#
#
#     50%    75%   max
# 0  36.0  46.00  80.0
# 1  33.0  43.75  75.0
# 2  37.0  46.00  90.0
# ...

# %%
# Among whom is the proportion of those who earn a lot (>50K) greater: married or
# single men (marital-status feature)? Consider as married those who have
# a marital-status starting with Married (Married-civ-spouse, Married-spouse-absent
# or Married-AF-spouse), the rest are considered bachelors.
df_income = df['income']
df[df_income =='>50K']['marital-status'].str.contains('Married-').value_counts()
# Out:
# marital-status
# True     6736
# False    1105
# Name: count, dtype: int64

# %%
# What is the maximum number of hours a person works per week
# (hours-per-week feature)? How many people work such a number of hours, and
# what is the percentage of those who earn a lot (>50K) among them?

max_hours = df['hours-per-week'].max()
df['income'][df['hours-per-week'] == max_hours].value_counts(normalize=True)*100
# print(percent_country['Germany'])
# Out:
# income
# <=50K    70.588235
# >50K     29.411765
# Name: proportion, dtype: float64
